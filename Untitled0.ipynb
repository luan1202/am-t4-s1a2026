# %% [markdown]
# <a href="https://colab.research.google.com/github/luan1202/am-t4-s1a2026/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introdução de Python

# %%
a=1
b=2
print("A soma é", a+b)
# Out:
# A soma é 3

# %% [markdown]
# #Segunda Camada

# %%
c=4
d=5
print("A multiplicação é", c*d)
# Out:
# A multiplicação é 20

# %% [markdown]
# #Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Número sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# #Teste de Funções Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 1)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

eq += equacao2grau(a, b, c)
print(eq)
# Out:
# (2.0, 1.0, -2.414213562373095, 0.41421356237309515, 0.5, 1.5)

# %%
import random

for i in range(5):
  a = random.randint(-5, 1)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

eq += equacao2grau(a, b, c)

print(eq[0])
# Out:
# 2.0

# %%
for i in range(len(eq)):
  if( i % 2 == 0):
    if(eq[i] != 'Número sem raiz'):
      print('X1: [',eq[i],']')
  else:
    if(eq[i] != 'Número sem raiz'):
      print('X2: [',eq[i],']\n')
# Out:
# X1: [ 2.0 ]
# X2: [ 1.0 ]
#
# X1: [ -2.414213562373095 ]
# X2: [ 0.41421356237309515 ]
#
# X1: [ 0.5 ]
# X2: [ 1.5 ]
#
# X1: [ -0.715549442140351 ]
# X2: [ 2.515549442140351 ]
